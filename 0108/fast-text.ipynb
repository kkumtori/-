# %%
# !pip install fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 KB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.10.3-py3-none-any.whl (222 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp38-cp38-linux_x86_64.whl size=3127895 sha256=02144092da9e431977fab73e177312a00b6fc6b0a10495cf424831bda991b39c
#   Stored in directory: /root/.cache/pip/wheels/93/61/2a/c54711a91c418ba06ba195b1d78ff24fcaad8592f2a694ac94
# Successfully built fasttext
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/핑크핑크/노/orderqueen.csv')

# %%
fast=pd.DataFrame(columns=['document','label'])

# %%
fast['document']=data['MENU_FULL_NM']
fast['label']='__label__'+data['label']

# %%
fast.head()
# Out:
#   document        label
# 0      3단계  __label__옵션
# 1     밀떡변경  __label__옵션
# 2    분모자변경  __label__옵션
# 3      파마산  __label__옵션
# 4      콩가루  __label__옵션

# %%
import fasttext

# %%
fast.to_csv('/content/drive/MyDrive/핑크핑크/노/fast.txt', sep = '\t', index = False)

# %%
model = fasttext.train_supervised('/content/drive/MyDrive/핑크핑크/노/fast.txt', wordNgrams=2, epoch=25, lr=0.35)

# %%
df2=pd.read_csv('/content/drive/MyDrive/핑크핑크/고뇽/오더퀸.csv',encoding='euckr')

# %%
model.predict('망했다')
# Out:
# (('__label__drop',), array([0.22127149]))

# %%
fast[fast['document']=='2단계']
# Out:
# Empty DataFrame
# Columns: [document, label]
# Index: []

# %%
fast
# Out:
#          document           label
# 0             3단계     __label__옵션
# 1            밀떡변경     __label__옵션
# 2           분모자변경     __label__옵션
# 3             파마산     __label__옵션
# 4             콩가루     __label__옵션
# ..            ...             ...
# 294        건포도 스콘     __label__스콘
# 295         호두 스콘     __label__스콘
# 296     바닐라 젤라소프트  __label__아이스크림
# 297  바닐라&초코 젤라소프트  __label__아이스크림
# 298      망고 젤라소프트  __label__아이스크림
#
# [299 rows x 2 columns]
