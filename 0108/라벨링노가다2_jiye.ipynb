# %%
cd /content/drive/MyDrive/핑크핑크
# Out:
# /content/drive/MyDrive/핑크핑크

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('해커톤참고자료.xlsx')

# %%
data['label']=None

# %%
data.loc[:10,'label']=['카페라떼','샌드위치+아메리카노','초코 도넛','우유 생크림 도넛','얼그레이 커스터드 도넛','도넛 박스','블루베리 요거트 아이스크림','마카롱','목살구이','냉면 + 군만두','냉소바 + 군만두']

# %%
data.loc[11:20,'label']=['?','물냉면 + 군만두','?','스페셜마리2','냉소바 + 돈가스','?','?','drop','drop','옵션']

# %%
data.loc[21:30,'label']=['김치 치즈 볶음밥','회덮밥','김치 카츠 나베','스테이크','페퍼민트','캐모마일','바닐라라떼','drop','등심 미소카츠','말차라떼']

# %%
data.loc[31:40,'label']=['얼그레이','카페라떼','아메리카노','바닐라라떼','케익','케익','아몬드 과자','케이크','환타','크로플']

# %%
data.loc[41:50,'label']=['케이크','우유 카스테라 도넛','우유 딸기 카스테라 도넛','drop','drop','drop','?','필터커피','필터커피']

# %%
data.to_csv('data.csv',index=False)
