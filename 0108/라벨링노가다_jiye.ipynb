# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - **지예**: 오더퀸 200번~오늘데이터 끝까지 (350개)
# - **건영**: 우노스 340\~끝,오더퀸 1\m~200개 (370개)
# - **지원**: 우노스,,? 1~ 340 (340개)

# %%
cd /content/drive/MyDrive/핑크핑크
# Out:
# /content/drive/MyDrive/핑크핑크

# %%
order=pd.read_csv('비버웍스_샘플데이터_open.xlsx - 오더퀸.csv')

# %%
data=order.iloc[200:,:]

# %%
data=data.reset_index()

# %%
data['label']=None

# %%
data.loc[:10,'label']='옵션'

# %%
data.loc[11:20,'label']=['drop','순살 치킨','떡볶이','카스','테라','카프리','처음처럼','참이슬 fresh','진로','?']

# %%
data.loc[21:30,'label']=['순살 치킨','떡볶이 튀김 세트','?','?','초밥','초밥','초밥','초밥','초밥','초밥']

# %%
data.loc[31:40,'label']='초밥'

# %%
data.loc[41:50,'label']=['초밥']*5+['롤']*5

# %%
data.loc[51:60,'label']=['롤','롤','우동','우동','고로케','튀김','타코야끼','돈까스+초밥','돈까스+초밥','냉모밀']

# %%
data.loc[61:70,'label']=['콜라','사이다','미린다','밀키스','마운틴듀','대선','참이슬','좋은데이','진로','테라']

# %%
data.loc[71:80,'label']=['카스','클라우드','처음처럼','스파클링','스파클링']+['옵션']*5

# %%
data.loc[81:90,'label']='옵션'

# %%
data.loc[91:100,'label']='옵션'

# %%
data.loc[101:110,'label']='옵션'

# %%
data.loc[111:120,'label']=['옵션']*3+['drop']*7

# %%
data.loc[121:130,'label']=['drop']*7+['카페라떼','바닐라라떼','헤이즐넛아메리카노']

# %%
data.loc[131:140,'label']=['연유라떼','카라멜마끼아또','카페모카','민트모카','꿀 아메리카노','꿀 카페라떼','치즈크림 아메리카노','치즈크림 카페라떼','옵션','아메리카노']

# %%
data.loc[141:150,'label']=['아메리카노','아메리카노','카푸치노','초코라떼','녹차라떼','밀크티','고구마라떼','흑임자라떼','딸기라떼','민트초코라떼']

# %%
data.loc[151:160,'label']=['이천쌀라떼','초코버블라떼','그린티버블라떼','쿠앤크버블라떼','딸기버블라떼','흑당버블라떼','오곡라떼','커피 프라페','헤이즐넛 프라페','녹차 프라페']

# %%
data.loc[161:170,'label']=['민트초코칩 프라페','자바칩 프라페','쿠앤크 프라페','이천쌀 프라페','플레인 요거트 스무디','딸기 요거트 스무디','망고 요거트 스무디','자두 요거트 스무디','큐브 수박 스무디','큐브 망고 스무디']

# %%
data.loc[171:180,'label']=data.loc[171:180,'MENU_NM']

# %%
data.loc[181:190,'label']=['고구마+아메리카노','고구마+카페라떼','?','딸기 주스','바나나 주스','딸기 바나나 주스','키위 주스','토마토 주스','오렌지 주스','블루베리 주스']

# %%
data.loc[191:200,'label']=['망고 주스','핑크 레몬 에이드','블루 레몬 에이드','청포도 에이드','자몽 에이드','자두 에이드','복숭아 아이스티','얼그레이','캐모마일','레몬그라스']

# %%
data.loc[201:210,'label']=['유자차','꿀 레몬그라스차','꿀 블랙오미자차','아이스티','쿠키','베이글칩','웨하스','스투룹 와플','초콜릿','초코 머핀']

# %%
data.loc[211:220,'label']=['비스킷 슈','카스테라','캐이크','모카번','머핀','마카롱','프레즐','베이글','페스츄리','크로크무슈']

# %%
data.loc[221:230,'label']=['떡볶이','치즈 떡볶이']+['고구마']*5+['와플']*3

# %%
data.loc[231:240,'label']=['와플']*8+['시나몬 바케트 볼','스콘']

# %%
data.loc[241:250,'label']=['머핀']+['브라우니']*2+['크로플']*7

# %%
data.loc[251:260,'label']=['크로플']*5+['아이스크림']+['아포카토']+['아이스크림']*3

# %%
data.loc[261:270,'label']=['아이스크림']*2+['옵션']*8

# %%
data.loc[271:280,'label']=['쿠키']*3+['베이글칩']*2+['웨하스']*2+['초콜릿']*2+['비스킷 슈']

# %%
data.loc[281:290,'label']=['비스킷슈','케이크','케이크','머핀','머핀']+['마카롱']*5

# %%
data.loc[291:300,'label']=['베이글']*3+['스콘']*2+['아이스크림']*3

# %%
data.to_csv('orderqueen.csv',index=False)
